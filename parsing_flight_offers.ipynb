# %%
import json
import pandas as pd

# %%
with open('flight_offers.json', 'r') as file:
    data = json.load(file)

# %%
data
# Out:
# {'offer0': {'type': 'flight-offer',
#   'id': '1',
#   'source': 'GDS',
#   'instantTicketingRequired': False,
#   'nonHomogeneous': False,
#   'oneWay': False,
#   'isUpsellOffer': False,
#   'lastTicketingDate': '2025-02-26',
#   'lastTicketingDateTime': '2025-02-26',
#   'numberOfBookableSeats': 3,
#   'itineraries': [{'duration': 'PT10H48M',
#     'segments': [{'departure': {'iataCode': 'MSN',
#        'at': '2025-03-01T15:35:00'},
#       'arrival': {'iataCode': 'DEN', 'at': '2025-03-01T17:09:00'},
#       'carrierCode': 'F9',
#       'number': '1559',
#       'aircraft': {'code': '32N'},
#       'operating': {'carrierCode': 'F9'},
#       'duration': 'PT2H34M',
#       'id': '29',
#       'numberOfStops': 0,
#       'blacklistedInEU': False},
#      {'departure': {'iataCode': 'DEN', 'at': '2025-03-01T23:27:00'},
#       'arrival': {'iataCode': 'PHX',
#        'terminal': '3',
#        'at': '2025-03-02T01:23:00'},
#       'carrierCode': 'F9',
#       'number': '4753',
# ...
